# %%
# !pip install pycaret &> /dev/null

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# 17                         telescope  Multivariate
# 18                           titanic  Multivariate
# 19  us_presidential_election_results  Multivariate
# 20                             glass  Multivariate
# 21                              iris  Multivariate
# 22                             poker  Multivariate
# 23                         questions  Multivariate
# 24                         satellite  Multivariate
# 25                               CTG  Multivariate
# 26                          asia_gdp  Multivariate
# 27                         elections  Multivariate
# 28                          facebook  Multivariate
# 29                               ipl  Multivariate
# 30                         jewellery  Multivariate
# 31                              mice  Multivariate
# 32                         migration  Multivariate
# 33                           perfume  Multivariate
# 34                           pokemon  Multivariate
# 35                        population  Multivariate
# 36                     public_health  Multivariate
# 37                             seeds  Multivariate
# 38                         wholesale  Multivariate
# 39                            tweets          Text
# 40                            amazon          Text
# 41                              kiva          Text
# 42                               spx          Text
# 43                         wikipedia          Text
# 44                        automobile  Multivariate
# 45                              bike  Multivariate
# 46                            boston  Multivariate
# 47                          concrete  Multivariate
# 48                           diamond  Multivariate
# 49                            energy  Multivariate
# 50                            forest  Multivariate
# 51                              gold  Multivariate
# 52                             house  Multivariate
# 53                         insurance  Multivariate
# 54                        parkinsons  Multivariate
# 55                           traffic  Multivariate
#
#                    Default Task Target Variable 1 Target Variable 2  \
# 0             Anomaly Detection              None              None
# 1       Association Rule Mining         InvoiceNo       Description
# 2       Association Rule Mining         InvoiceNo       Description
# 3       Classification (Binary)           deposit              None
# 4       Classification (Binary)             Class              None
# 5       Classification (Binary)             Class              None
# 6       Classification (Binary)           default              None
# 7       Classification (Binary)    Class variable              None
# 8       Classification (Binary)             stabf              None
# 9       Classification (Binary)              left              None
# 10      Classification (Binary)             DEATH              None
# 11      Classification (Binary)           Disease              None
# 12      Classification (Binary)             Class              None
# 13      Classification (Binary)       income >50K              None
# 14      Classification (Binary)          Purchase              None
# 15      Classification (Binary)       TARGET_5Yrs              None
# 16      Classification (Binary)              type              None
# 17      Classification (Binary)             Class              None
# 18      Classification (Binary)          Survived              None
# 19      Classification (Binary)      party_winner              None
# 20  Classification (Multiclass)              Type              None
# 21  Classification (Multiclass)           species              None
# 22  Classification (Multiclass)             CLASS              None
# 23  Classification (Multiclass)     Next_Question              None
# 24  Classification (Multiclass)             Class              None
# 25  Classification (Multiclass)               NSP              None
# 26                   Clustering              None              None
# 27                   Clustering              None              None
# 28                   Clustering              None              None
# 29                   Clustering              None              None
# 30                   Clustering              None              None
# 31                   Clustering              None              None
# 32                   Clustering              None              None
# 33                   Clustering              None              None
# 34                   Clustering              None              None
# 35                   Clustering              None              None
# 36                   Clustering              None              None
# 37                   Clustering              None              None
# 38                   Clustering              None              None
# 39                          NLP             tweet              None
# 40         NLP / Classification        reviewText              None
# 41         NLP / Classification                en              None
# 42             NLP / Regression              text              None
# 43         NLP / Classification              Text              None
# 44                   Regression             price              None
# 45                   Regression               cnt              None
# 46                   Regression              medv              None
# 47                   Regression          strength              None
# 48                   Regression             Price              None
# 49                   Regression      Heating Load      Cooling Load
# 50                   Regression              area              None
# 51                   Regression         Gold_T+22              None
# 52                   Regression         SalePrice              None
# 53                   Regression           charges              None
# 54                   Regression               PPE              None
# 55                   Regression    traffic_volume              None
#
#     # Instances  # Attributes Missing Values
# 0          1000            10              N
# 1          8557             8              N
# 2          9495             8              N
# 3         45211            17              N
# 4           748             5              N
# 5           683            10              N
# 6         24000            24              N
# 7           768             9              N
# 8         10000            14              N
# 9         14999            10              N
# 10          200            16              N
# 11          270            14              N
# 12          154            32              Y
# 13        32561            14              Y
# 14         1070            15              N
# 15         1340            21              N
# 16         6498            13              N
# 17        19020            11              N
# 18          891            11              Y
# 19          497             7              N
# 20          214            10              N
# 21          150             5              N
# 22       100000            11              N
# 23          499             4              N
# 24         6435            37              N
# 25         2129            40              Y
# 26           40            11              N
# 27         3195            54              Y
# 28         7050            12              N
# 29          153            25              N
# 30          505             4              N
# 31         1080            82              Y
# 32          233            12              N
# 33           20            29              N
# 34          800            13              Y
# 35          255            56              Y
# 36          224            21              N
# 37          210             7              N
# 38          440             8              N
# 39         8594             2              N
# 40        20000             2              N
# 41         6818             7              N
# 42          874             4              N
# 43          500             3              N
# 44          202            26              Y
# 45        17379            15              N
# 46          506            14              N
# 47         1030             9              N
# 48         6000             8              N
# 49          768            10              N
# 50          517            13              N
# 51         2558           121              N
# 52         1461            81              Y
# 53         1338             7              N
# 54         5875            22              N
# 55        48204             8              N

# %%
df = get_data('perfume', verbose=False)

# %%
df.to_csv("perfume.csv")
from google.colab import files
files.download('perfume.csv')

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

# %% [markdown]
# Using Normalization

# %%
setup(data = df, normalize = True, normalize_method = 'zscore', verbose=False)

# %%
print("K-Means Clustering")
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

print("Agglomerative Clustering")
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)

print("OPTICS Clustering ")
print("For Cluster = 3")
x = create_model('optics', num_clusters = 3)

print("For Cluster = 4")
x = create_model('optics', num_clusters = 4)

print("For Cluster = 5")
x = create_model('optics', num_clusters = 5)

print("For Cluster = 6")
x = create_model('optics', num_clusters = 6)
# Out:
# K-Means CLustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_d93f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d93f8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d93f8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d93f8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d93f8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d93f8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d93f8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d93f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d93f8_row0_col0" class="data row0 col0" >0.5122</td>
#       <td id="T_d93f8_row0_col1" class="data row0 col1" >34.8407</td>
#       <td id="T_d93f8_row0_col2" class="data row0 col2" >0.5575</td>
#       <td id="T_d93f8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d93f8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d93f8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_39f9f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39f9f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_39f9f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_39f9f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_39f9f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_39f9f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_39f9f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39f9f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39f9f_row0_col0" class="data row0 col0" >0.5117</td>
#       <td id="T_39f9f_row0_col1" class="data row0 col1" >58.5519</td>
#       <td id="T_39f9f_row0_col2" class="data row0 col2" >0.3992</td>
#       <td id="T_39f9f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_39f9f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_39f9f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_c98c5" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c98c5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c98c5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c98c5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c98c5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c98c5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c98c5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c98c5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c98c5_row0_col0" class="data row0 col0" >0.5151</td>
#       <td id="T_c98c5_row0_col1" class="data row0 col1" >86.2262</td>
#       <td id="T_c98c5_row0_col2" class="data row0 col2" >0.3779</td>
#       <td id="T_c98c5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c98c5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c98c5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_e28c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e28c3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e28c3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e28c3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e28c3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e28c3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e28c3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e28c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e28c3_row0_col0" class="data row0 col0" >0.4782</td>
#       <td id="T_e28c3_row0_col1" class="data row0 col1" >89.3950</td>
#       <td id="T_e28c3_row0_col2" class="data row0 col2" >0.4320</td>
#       <td id="T_e28c3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e28c3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e28c3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Agglomerative Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_079e4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_079e4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_079e4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_079e4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_079e4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_079e4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_079e4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_079e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_079e4_row0_col0" class="data row0 col0" >0.5489</td>
#       <td id="T_079e4_row0_col1" class="data row0 col1" >26.4198</td>
#       <td id="T_079e4_row0_col2" class="data row0 col2" >0.3187</td>
#       <td id="T_079e4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_079e4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_079e4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_a2c46" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2c46_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a2c46_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a2c46_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a2c46_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a2c46_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a2c46_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2c46_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2c46_row0_col0" class="data row0 col0" >0.4839</td>
#       <td id="T_a2c46_row0_col1" class="data row0 col1" >48.1970</td>
#       <td id="T_a2c46_row0_col2" class="data row0 col2" >0.3677</td>
#       <td id="T_a2c46_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a2c46_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a2c46_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_fac6f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fac6f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fac6f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fac6f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fac6f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fac6f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fac6f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fac6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fac6f_row0_col0" class="data row0 col0" >0.5068</td>
#       <td id="T_fac6f_row0_col1" class="data row0 col1" >80.6019</td>
#       <td id="T_fac6f_row0_col2" class="data row0 col2" >0.3685</td>
#       <td id="T_fac6f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fac6f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fac6f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_8ceea" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ceea_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8ceea_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8ceea_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8ceea_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8ceea_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8ceea_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ceea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ceea_row0_col0" class="data row0 col0" >0.4782</td>
#       <td id="T_8ceea_row0_col1" class="data row0 col1" >89.3950</td>
#       <td id="T_8ceea_row0_col2" class="data row0 col2" >0.4320</td>
#       <td id="T_8ceea_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8ceea_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8ceea_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# OPTICS Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8df20" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8df20_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8df20_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8df20_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8df20_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8df20_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8df20_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8df20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8df20_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_8df20_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_8df20_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_8df20_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8df20_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8df20_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_74b26" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74b26_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_74b26_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_74b26_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_74b26_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_74b26_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_74b26_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74b26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_74b26_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_74b26_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_74b26_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_74b26_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_74b26_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_74b26_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_f46a9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f46a9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f46a9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f46a9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f46a9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f46a9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f46a9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f46a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f46a9_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_f46a9_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_f46a9_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_f46a9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f46a9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f46a9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_00287" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00287_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_00287_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_00287_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_00287_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_00287_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_00287_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00287_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00287_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_00287_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_00287_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_00287_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_00287_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_00287_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Using Transformation

# %%
setup(data = df, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("K-Means CLustering")
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

print("Agglomerative Clustering")
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)

print("OPTICS Clustering ")
print("For Cluster = 3")
x = create_model('optics', num_clusters = 3)

print("For Cluster = 4")
x = create_model('optics', num_clusters = 4)

print("For Cluster = 5")
x = create_model('optics', num_clusters = 5)

print("For Cluster = 6")
x = create_model('optics', num_clusters = 6)
# Out:
# K-Means CLustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_4f23b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f23b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_4f23b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_4f23b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_4f23b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_4f23b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_4f23b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f23b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f23b_row0_col0" class="data row0 col0" >0.5122</td>
#       <td id="T_4f23b_row0_col1" class="data row0 col1" >34.8407</td>
#       <td id="T_4f23b_row0_col2" class="data row0 col2" >0.5575</td>
#       <td id="T_4f23b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_4f23b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_4f23b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_ab6de" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ab6de_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ab6de_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ab6de_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ab6de_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ab6de_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ab6de_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ab6de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ab6de_row0_col0" class="data row0 col0" >0.5117</td>
#       <td id="T_ab6de_row0_col1" class="data row0 col1" >58.5519</td>
#       <td id="T_ab6de_row0_col2" class="data row0 col2" >0.3992</td>
#       <td id="T_ab6de_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ab6de_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ab6de_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_b8177" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8177_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b8177_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b8177_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b8177_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b8177_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b8177_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8177_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8177_row0_col0" class="data row0 col0" >0.5151</td>
#       <td id="T_b8177_row0_col1" class="data row0 col1" >86.2262</td>
#       <td id="T_b8177_row0_col2" class="data row0 col2" >0.3779</td>
#       <td id="T_b8177_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b8177_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b8177_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_c7408" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7408_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c7408_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c7408_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c7408_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c7408_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c7408_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7408_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7408_row0_col0" class="data row0 col0" >0.4782</td>
#       <td id="T_c7408_row0_col1" class="data row0 col1" >89.3950</td>
#       <td id="T_c7408_row0_col2" class="data row0 col2" >0.4320</td>
#       <td id="T_c7408_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c7408_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c7408_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Agglomerative Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_db6dc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db6dc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_db6dc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_db6dc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_db6dc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_db6dc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_db6dc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db6dc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db6dc_row0_col0" class="data row0 col0" >0.5489</td>
#       <td id="T_db6dc_row0_col1" class="data row0 col1" >26.4198</td>
#       <td id="T_db6dc_row0_col2" class="data row0 col2" >0.3187</td>
#       <td id="T_db6dc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_db6dc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_db6dc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_0965c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0965c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0965c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0965c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0965c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0965c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0965c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0965c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0965c_row0_col0" class="data row0 col0" >0.4839</td>
#       <td id="T_0965c_row0_col1" class="data row0 col1" >48.1970</td>
#       <td id="T_0965c_row0_col2" class="data row0 col2" >0.3677</td>
#       <td id="T_0965c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0965c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0965c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_ecce6" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecce6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ecce6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ecce6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ecce6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ecce6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ecce6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecce6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ecce6_row0_col0" class="data row0 col0" >0.5068</td>
#       <td id="T_ecce6_row0_col1" class="data row0 col1" >80.6019</td>
#       <td id="T_ecce6_row0_col2" class="data row0 col2" >0.3685</td>
#       <td id="T_ecce6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ecce6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ecce6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_38077" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38077_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_38077_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_38077_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_38077_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_38077_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_38077_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38077_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38077_row0_col0" class="data row0 col0" >0.4782</td>
#       <td id="T_38077_row0_col1" class="data row0 col1" >89.3950</td>
#       <td id="T_38077_row0_col2" class="data row0 col2" >0.4320</td>
#       <td id="T_38077_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_38077_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_38077_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# OPTICS Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_5ddc0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ddc0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ddc0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ddc0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ddc0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ddc0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ddc0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ddc0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ddc0_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_5ddc0_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_5ddc0_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_5ddc0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5ddc0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5ddc0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_9d059" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d059_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9d059_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9d059_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9d059_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9d059_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9d059_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d059_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d059_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_9d059_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_9d059_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_9d059_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9d059_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9d059_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_fbc47" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fbc47_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fbc47_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fbc47_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fbc47_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fbc47_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fbc47_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fbc47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fbc47_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_fbc47_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_fbc47_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_fbc47_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fbc47_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fbc47_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_88a27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88a27_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_88a27_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_88a27_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_88a27_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_88a27_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_88a27_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88a27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88a27_row0_col0" class="data row0 col0" >0.2216</td>
#       <td id="T_88a27_row0_col1" class="data row0 col1" >0.7416</td>
#       <td id="T_88a27_row0_col2" class="data row0 col2" >5.6860</td>
#       <td id="T_88a27_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_88a27_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_88a27_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Using PCA

# %%
setup(data = df, pca = True, pca_method = 'linear', verbose=False)

print("K-Means CLustering")
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

print("Agglomerative Clustering")
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)

print("OPTICS Clustering ")
print("For Cluster = 3")
x = create_model('optics', num_clusters = 3)

print("For Cluster = 4")
x = create_model('optics', num_clusters = 4)

print("For Cluster = 5")
x = create_model('optics', num_clusters = 5)

print("For Cluster = 6")
x = create_model('optics', num_clusters = 6)
# Out:
# K-Means CLustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_8f45a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f45a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_8f45a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_8f45a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_8f45a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_8f45a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_8f45a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f45a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8f45a_row0_col0" class="data row0 col0" >0.5192</td>
#       <td id="T_8f45a_row0_col1" class="data row0 col1" >31.5178</td>
#       <td id="T_8f45a_row0_col2" class="data row0 col2" >0.5722</td>
#       <td id="T_8f45a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_8f45a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_8f45a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_49445" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49445_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_49445_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_49445_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_49445_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_49445_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_49445_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49445_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49445_row0_col0" class="data row0 col0" >0.5087</td>
#       <td id="T_49445_row0_col1" class="data row0 col1" >61.1216</td>
#       <td id="T_49445_row0_col2" class="data row0 col2" >0.4182</td>
#       <td id="T_49445_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_49445_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_49445_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_ec764" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ec764_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ec764_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ec764_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ec764_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ec764_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ec764_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ec764_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ec764_row0_col0" class="data row0 col0" >0.5101</td>
#       <td id="T_ec764_row0_col1" class="data row0 col1" >92.1660</td>
#       <td id="T_ec764_row0_col2" class="data row0 col2" >0.3791</td>
#       <td id="T_ec764_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ec764_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ec764_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_fd00b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd00b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fd00b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fd00b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fd00b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fd00b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fd00b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd00b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd00b_row0_col0" class="data row0 col0" >0.4819</td>
#       <td id="T_fd00b_row0_col1" class="data row0 col1" >103.1940</td>
#       <td id="T_fd00b_row0_col2" class="data row0 col2" >0.4291</td>
#       <td id="T_fd00b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fd00b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fd00b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Agglomerative Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_29e8c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29e8c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_29e8c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_29e8c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_29e8c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_29e8c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_29e8c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29e8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29e8c_row0_col0" class="data row0 col0" >0.4754</td>
#       <td id="T_29e8c_row0_col1" class="data row0 col1" >27.8153</td>
#       <td id="T_29e8c_row0_col2" class="data row0 col2" >0.4972</td>
#       <td id="T_29e8c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_29e8c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_29e8c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_d50d3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d50d3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d50d3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d50d3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d50d3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d50d3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d50d3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d50d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d50d3_row0_col0" class="data row0 col0" >0.4802</td>
#       <td id="T_d50d3_row0_col1" class="data row0 col1" >48.5003</td>
#       <td id="T_d50d3_row0_col2" class="data row0 col2" >0.3685</td>
#       <td id="T_d50d3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d50d3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d50d3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_6a5b2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a5b2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6a5b2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6a5b2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6a5b2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6a5b2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6a5b2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a5b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a5b2_row0_col0" class="data row0 col0" >0.5072</td>
#       <td id="T_6a5b2_row0_col1" class="data row0 col1" >86.9310</td>
#       <td id="T_6a5b2_row0_col2" class="data row0 col2" >0.3699</td>
#       <td id="T_6a5b2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6a5b2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6a5b2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_80783" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80783_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_80783_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_80783_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_80783_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_80783_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_80783_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80783_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80783_row0_col0" class="data row0 col0" >0.4827</td>
#       <td id="T_80783_row0_col1" class="data row0 col1" >101.7873</td>
#       <td id="T_80783_row0_col2" class="data row0 col2" >0.4260</td>
#       <td id="T_80783_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_80783_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_80783_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# OPTICS Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_81d62" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81d62_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_81d62_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_81d62_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_81d62_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_81d62_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_81d62_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81d62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81d62_row0_col0" class="data row0 col0" >0.0088</td>
#       <td id="T_81d62_row0_col1" class="data row0 col1" >0.4989</td>
#       <td id="T_81d62_row0_col2" class="data row0 col2" >3.3187</td>
#       <td id="T_81d62_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_81d62_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_81d62_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_c7d0a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7d0a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c7d0a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c7d0a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c7d0a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c7d0a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c7d0a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7d0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7d0a_row0_col0" class="data row0 col0" >0.0088</td>
#       <td id="T_c7d0a_row0_col1" class="data row0 col1" >0.4989</td>
#       <td id="T_c7d0a_row0_col2" class="data row0 col2" >3.3187</td>
#       <td id="T_c7d0a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c7d0a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c7d0a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_7d352" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d352_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7d352_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7d352_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7d352_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7d352_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7d352_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d352_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d352_row0_col0" class="data row0 col0" >0.0088</td>
#       <td id="T_7d352_row0_col1" class="data row0 col1" >0.4989</td>
#       <td id="T_7d352_row0_col2" class="data row0 col2" >3.3187</td>
#       <td id="T_7d352_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7d352_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7d352_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_e38fe" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e38fe_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e38fe_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e38fe_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e38fe_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e38fe_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e38fe_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e38fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e38fe_row0_col0" class="data row0 col0" >0.0088</td>
#       <td id="T_e38fe_row0_col1" class="data row0 col1" >0.4989</td>
#       <td id="T_e38fe_row0_col2" class="data row0 col2" >3.3187</td>
#       <td id="T_e38fe_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e38fe_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e38fe_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Using Transformation+Normalization

# %%
setup(data = df, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("K-Means CLustering")
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

print("Agglomerative Clustering")
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)

print("OPTICS Clustering ")
print("For Cluster = 3")
x = create_model('optics', num_clusters = 3)

print("For Cluster = 4")
x = create_model('optics', num_clusters = 4)

print("For Cluster = 5")
x = create_model('optics', num_clusters = 5)

print("For Cluster = 6")
x = create_model('optics', num_clusters = 6)
# Out:
# K-Means CLustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_620be" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_620be_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_620be_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_620be_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_620be_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_620be_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_620be_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_620be_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_620be_row0_col0" class="data row0 col0" >0.1966</td>
#       <td id="T_620be_row0_col1" class="data row0 col1" >8.8376</td>
#       <td id="T_620be_row0_col2" class="data row0 col2" >1.3197</td>
#       <td id="T_620be_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_620be_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_620be_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_143bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_143bb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_143bb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_143bb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_143bb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_143bb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_143bb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_143bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_143bb_row0_col0" class="data row0 col0" >0.1583</td>
#       <td id="T_143bb_row0_col1" class="data row0 col1" >8.0503</td>
#       <td id="T_143bb_row0_col2" class="data row0 col2" >1.2318</td>
#       <td id="T_143bb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_143bb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_143bb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_0301a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0301a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0301a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0301a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0301a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0301a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0301a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0301a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0301a_row0_col0" class="data row0 col0" >0.1092</td>
#       <td id="T_0301a_row0_col1" class="data row0 col1" >6.8336</td>
#       <td id="T_0301a_row0_col2" class="data row0 col2" >1.3937</td>
#       <td id="T_0301a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0301a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0301a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_98076" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98076_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_98076_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_98076_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_98076_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_98076_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_98076_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98076_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98076_row0_col0" class="data row0 col0" >0.0709</td>
#       <td id="T_98076_row0_col1" class="data row0 col1" >5.8185</td>
#       <td id="T_98076_row0_col2" class="data row0 col2" >1.2721</td>
#       <td id="T_98076_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_98076_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_98076_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Agglomerative Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_1f5f8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f5f8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1f5f8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1f5f8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1f5f8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1f5f8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1f5f8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f5f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f5f8_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_1f5f8_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_1f5f8_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_1f5f8_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1f5f8_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1f5f8_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_df10d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df10d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_df10d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_df10d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_df10d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_df10d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_df10d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df10d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df10d_row0_col0" class="data row0 col0" >0.1470</td>
#       <td id="T_df10d_row0_col1" class="data row0 col1" >7.7399</td>
#       <td id="T_df10d_row0_col2" class="data row0 col2" >1.2094</td>
#       <td id="T_df10d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_df10d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_df10d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_89015" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89015_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_89015_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_89015_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_89015_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_89015_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_89015_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89015_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89015_row0_col0" class="data row0 col0" >0.1092</td>
#       <td id="T_89015_row0_col1" class="data row0 col1" >6.8336</td>
#       <td id="T_89015_row0_col2" class="data row0 col2" >1.3937</td>
#       <td id="T_89015_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_89015_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_89015_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_9ee43" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ee43_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9ee43_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9ee43_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9ee43_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9ee43_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9ee43_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ee43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ee43_row0_col0" class="data row0 col0" >0.0778</td>
#       <td id="T_9ee43_row0_col1" class="data row0 col1" >5.8406</td>
#       <td id="T_9ee43_row0_col2" class="data row0 col2" >1.5400</td>
#       <td id="T_9ee43_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9ee43_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9ee43_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# OPTICS Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_53016" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_53016_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_53016_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_53016_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_53016_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_53016_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_53016_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_53016_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_53016_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_53016_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_53016_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_53016_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_53016_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_53016_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_6c8f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c8f1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6c8f1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6c8f1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6c8f1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6c8f1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6c8f1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c8f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c8f1_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6c8f1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_6c8f1_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_6c8f1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6c8f1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6c8f1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_1f533" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f533_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1f533_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1f533_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1f533_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1f533_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1f533_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f533_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f533_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1f533_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1f533_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_1f533_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1f533_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1f533_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_546b0" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_546b0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_546b0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_546b0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_546b0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_546b0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_546b0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_546b0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_546b0_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_546b0_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_546b0_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_546b0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_546b0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_546b0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Using Transformation+Normalization+PCA

# %%
setup(data = df, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("K-Means CLustering")
print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)

print("Agglomerative Clustering")
print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)

print("OPTICS Clustering ")
print("For Cluster = 3")
x = create_model('optics', num_clusters = 3)

print("For Cluster = 4")
x = create_model('optics', num_clusters = 4)

print("For Cluster = 5")
x = create_model('optics', num_clusters = 5)

print("For Cluster = 6")
x = create_model('optics', num_clusters = 6)
# Out:
# K-Means CLustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e79e3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e79e3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e79e3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e79e3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e79e3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e79e3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e79e3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e79e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e79e3_row0_col0" class="data row0 col0" >0.2094</td>
#       <td id="T_e79e3_row0_col1" class="data row0 col1" >8.9578</td>
#       <td id="T_e79e3_row0_col2" class="data row0 col2" >1.2590</td>
#       <td id="T_e79e3_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e79e3_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e79e3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_613bc" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_613bc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_613bc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_613bc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_613bc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_613bc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_613bc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_613bc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_613bc_row0_col0" class="data row0 col0" >0.1583</td>
#       <td id="T_613bc_row0_col1" class="data row0 col1" >8.0503</td>
#       <td id="T_613bc_row0_col2" class="data row0 col2" >1.2318</td>
#       <td id="T_613bc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_613bc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_613bc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_9bdee" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bdee_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9bdee_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9bdee_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9bdee_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9bdee_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9bdee_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bdee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bdee_row0_col0" class="data row0 col0" >0.1062</td>
#       <td id="T_9bdee_row0_col1" class="data row0 col1" >6.8773</td>
#       <td id="T_9bdee_row0_col2" class="data row0 col2" >1.4502</td>
#       <td id="T_9bdee_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9bdee_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9bdee_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_7d9e1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d9e1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7d9e1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7d9e1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7d9e1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7d9e1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7d9e1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d9e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d9e1_row0_col0" class="data row0 col0" >0.0767</td>
#       <td id="T_7d9e1_row0_col1" class="data row0 col1" >5.8470</td>
#       <td id="T_7d9e1_row0_col2" class="data row0 col2" >1.5769</td>
#       <td id="T_7d9e1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_7d9e1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_7d9e1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# Agglomerative Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_76f60" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76f60_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_76f60_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_76f60_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_76f60_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_76f60_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_76f60_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76f60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76f60_row0_col0" class="data row0 col0" >0.2859</td>
#       <td id="T_76f60_row0_col1" class="data row0 col1" >8.0950</td>
#       <td id="T_76f60_row0_col2" class="data row0 col2" >0.7250</td>
#       <td id="T_76f60_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_76f60_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_76f60_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_41578" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_41578_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_41578_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_41578_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_41578_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_41578_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_41578_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41578_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41578_row0_col0" class="data row0 col0" >0.1470</td>
#       <td id="T_41578_row0_col1" class="data row0 col1" >7.7399</td>
#       <td id="T_41578_row0_col2" class="data row0 col2" >1.2094</td>
#       <td id="T_41578_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_41578_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_41578_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_a45d4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a45d4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a45d4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a45d4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a45d4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a45d4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a45d4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a45d4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a45d4_row0_col0" class="data row0 col0" >0.1092</td>
#       <td id="T_a45d4_row0_col1" class="data row0 col1" >6.8336</td>
#       <td id="T_a45d4_row0_col2" class="data row0 col2" >1.3937</td>
#       <td id="T_a45d4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a45d4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a45d4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_d512e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d512e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d512e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d512e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d512e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d512e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d512e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d512e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d512e_row0_col0" class="data row0 col0" >0.0778</td>
#       <td id="T_d512e_row0_col1" class="data row0 col1" >5.8406</td>
#       <td id="T_d512e_row0_col2" class="data row0 col2" >1.5400</td>
#       <td id="T_d512e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d512e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d512e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# OPTICS Clustering
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_2f70b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2f70b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_2f70b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_2f70b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_2f70b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_2f70b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_2f70b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f70b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2f70b_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_2f70b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_2f70b_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_2f70b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_2f70b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_2f70b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_da48e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da48e_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_da48e_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_da48e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_da48e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_da48e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_da48e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da48e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da48e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_da48e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_da48e_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_da48e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_da48e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_da48e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_d4c94" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4c94_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d4c94_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d4c94_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d4c94_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d4c94_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d4c94_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4c94_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4c94_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d4c94_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d4c94_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_d4c94_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d4c94_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d4c94_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 6
# <style type="text/css">
# </style>
# <table id="T_3a333" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a333_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3a333_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3a333_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3a333_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3a333_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3a333_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a333_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a333_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3a333_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3a333_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_3a333_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_3a333_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_3a333_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
